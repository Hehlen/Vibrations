# %%
import MDAnalysis as mda
from MDAnalysis.lib import distances
import numpy as np
import matplotlib.pyplot as plt

strc_file = '../PROTEINS/CD16_old_dyna/CD16_DFTE_DFTE_nofuc/DYNA1_500ns/step3_input_no_water_no_ions.pdb'
traj_file = '../PROTEINS/CD16_old_dyna/CD16_DFTE_DFTE_nofuc/DYNA1_500ns/step3_input.pdb_aligned_no_water_no_ions.xtc'

# Load your trajectory and topology files
u = mda.Universe(strc_file, traj_file)

# %%
# Define a selection for sugars (modify based on your system)
sugar_selection = u.select_atoms("segid CARA or segid CARB or segid CARC")
unique_sugars = set(atom.resname for atom in sugar_selection.atoms)
print("Sugars in selected glycans:")
print(unique_sugars)
print()

# Print information about the selected sugars
print("Atoms in selected Sugars:")
print("segID resName resNum atomNum atomName")
for atom in sugar_selection:
    print(atom.segid, atom.resname, atom.resnum, atom.id, atom.name)
# Out:
# Sugars in selected glycans:
# {'BGLC', 'BGAL', 'BMAN', 'AFUC', 'AMAN'}
#
# Atoms in selected Sugars:
# segID resName resNum atomNum atomName
# CARA BGLC 1 6797 C1
# CARA BGLC 1 6798 H1
# CARA BGLC 1 6799 C5
# CARA BGLC 1 6800 H5
# CARA BGLC 1 6801 O5
# CARA BGLC 1 6802 C2
# CARA BGLC 1 6803 H2
# CARA BGLC 1 6804 N
# CARA BGLC 1 6805 HN
# CARA BGLC 1 6806 C
# CARA BGLC 1 6807 O
# CARA BGLC 1 6808 CT
# CARA BGLC 1 6809 HT1
# CARA BGLC 1 6810 HT2
# CARA BGLC 1 6811 HT3
# CARA BGLC 1 6812 C3
# CARA BGLC 1 6813 H3
# CARA BGLC 1 6814 O3
# CARA BGLC 1 6815 HO3
# CARA BGLC 1 6816 C4
# CARA BGLC 1 6817 H4
# CARA BGLC 1 6818 O4
# CARA BGLC 1 6819 C6
# CARA BGLC 1 6820 H61
# CARA BGLC 1 6821 H62
# CARA BGLC 1 6822 O6
# CARA BGLC 1 6823 HO6
# CARA BGLC 2 6824 C1
# CARA BGLC 2 6825 H1
# CARA BGLC 2 6826 C5
# CARA BGLC 2 6827 H5
# CARA BGLC 2 6828 O5
# CARA BGLC 2 6829 C2
# CARA BGLC 2 6830 H2
# CARA BGLC 2 6831 N
# CARA BGLC 2 6832 HN
# CARA BGLC 2 6833 C
# CARA BGLC 2 6834 O
# CARA BGLC 2 6835 CT
# CARA BGLC 2 6836 HT1
# CARA BGLC 2 6837 HT2
# CARA BGLC 2 6838 HT3
# CARA BGLC 2 6839 C3
# CARA BGLC 2 6840 H3
# CARA BGLC 2 6841 O3
# CARA BGLC 2 6842 HO3
# CARA BGLC 2 6843 C4
# CARA BGLC 2 6844 H4
# CARA BGLC 2 6845 O4
# CARA BGLC 2 6846 C6
# CARA BGLC 2 6847 H61
# CARA BGLC 2 6848 H62
# CARA BGLC 2 6849 O6
# CARA BGLC 2 6850 HO6
# CARC AMAN 4 9970 H61
# CARC AMAN 4 9971 H62
# CARC AMAN 4 9972 O6
# CARC AMAN 4 9973 HO6
# CARC BGLC 5 9974 C1
# CARC BGLC 5 9975 H1
# CARC BGLC 5 9976 C5
# CARC BGLC 5 9977 H5
# CARC BGLC 5 9978 O5
# CARC BGLC 5 9979 C2
# CARC BGLC 5 9980 H2
# CARC BGLC 5 9981 N
# CARC BGLC 5 9982 HN
# CARC BGLC 5 9983 C
# CARC BGLC 5 9984 O
# CARC BGLC 5 9985 CT
# CARC BGLC 5 9986 HT1
# CARC BGLC 5 9987 HT2
# CARC BGLC 5 9988 HT3
# CARC BGLC 5 9989 C3
# CARC BGLC 5 9990 H3
# CARC BGLC 5 9991 O3
# CARC BGLC 5 9992 HO3
# CARC BGLC 5 9993 C4
# CARC BGLC 5 9994 H4
# CARC BGLC 5 9995 O4
# CARC BGLC 5 9996 HO4
# CARC BGLC 5 9997 C6
# CARC BGLC 5 9998 H61
# CARC BGLC 5 9999 H62
# CARC BGLC 5 10000 O6
# CARC BGLC 5 10001 HO6
# CARC AMAN 6 10002 C1
# CARC AMAN 6 10003 H1
# CARC AMAN 6 10004 C5
# CARC AMAN 6 10005 H5
# CARC AMAN 6 10006 O5
# CARC AMAN 6 10007 C2
# CARC AMAN 6 10008 H2
# CARC AMAN 6 10009 O2
# CARC AMAN 6 10010 C3
# CARC AMAN 6 10011 H3
# CARC AMAN 6 10012 O3
# CARC AMAN 6 10013 HO3
# CARC AMAN 6 10014 C4
# CARC AMAN 6 10015 H4
# CARC AMAN 6 10016 O4
# CARC AMAN 6 10017 HO4
# CARC AMAN 6 10018 C6
# CARC AMAN 6 10019 H61
# CARC AMAN 6 10020 H62
# CARC AMAN 6 10021 O6
# CARC AMAN 6 10022 HO6
# CARC BGLC 7 10023 C1
# CARC BGLC 7 10024 H1
# CARC BGLC 7 10025 C5
# CARC BGLC 7 10026 H5
# CARC BGLC 7 10027 O5
# CARC BGLC 7 10028 C2
# CARC BGLC 7 10029 H2
# CARC BGLC 7 10030 N
# CARC BGLC 7 10031 HN
# CARC BGLC 7 10032 C
# CARC BGLC 7 10033 O
# CARC BGLC 7 10034 CT
# CARC BGLC 7 10035 HT1
# CARC BGLC 7 10036 HT2
# CARC BGLC 7 10037 HT3
# CARC BGLC 7 10038 C3
# CARC BGLC 7 10039 H3
# CARC BGLC 7 10040 O3
# CARC BGLC 7 10041 HO3
# CARC BGLC 7 10042 C4
# CARC BGLC 7 10043 H4
# CARC BGLC 7 10044 O4
# CARC BGLC 7 10045 HO4
# CARC BGLC 7 10046 C6
# CARC BGLC 7 10047 H61
# CARC BGLC 7 10048 H62
# CARC BGLC 7 10049 O6
# CARC BGLC 7 10050 HO6
# CARC AFUC 8 10051 C1
# CARC AFUC 8 10052 H1
# CARC AFUC 8 10053 C5
# CARC AFUC 8 10054 H5
# CARC AFUC 8 10055 O5
# CARC AFUC 8 10056 C2
# CARC AFUC 8 10057 H2
# CARC AFUC 8 10058 O2
# CARC AFUC 8 10059 HO2
# CARC AFUC 8 10060 C3
# CARC AFUC 8 10061 H3
# CARC AFUC 8 10062 O3
# CARC AFUC 8 10063 HO3
# CARC AFUC 8 10064 C4
# CARC AFUC 8 10065 H4
# CARC AFUC 8 10066 O4
# CARC AFUC 8 10067 HO4
# CARC AFUC 8 10068 C6
# CARC AFUC 8 10069 H61
# CARC AFUC 8 10070 H62
# CARC AFUC 8 10071 H63

# %%
strc_file = '
traj_file = '../PROTEINS/CD16_old_dyna/CD16_DFTE_DFTE_nofuc/DYNA1_500ns/step3_input.pdb_aligned_no_water_no_ions.xtc'

# Load your trajectory and topology files
u = mda.Universe(strc_file, traj_file)

# Print the unique segids and residue names to identify sugars
unique_segids = set(atom.segid for atom in u.atoms)
unique_residues = set(atom.resname for atom in u.atoms)
print("Unique SegIDs:", unique_segids)
print("Unique Residues:", unique_residues)
# Out:
# Unique SegIDs: {'CARD', 'PROA', 'CARC', 'PROC', 'CARA', 'CARB', 'PROB'}
# Unique Residues: {'CYS', 'THR', 'TYR', 'BGAL', 'BMAN', 'LEU', 'GLU', 'PRO', 'MET', 'GLY', 'AFUC', 'ALA', 'GLN', 'ASN', 'SER', 'BGLC', 'TRP', 'LYS', 'ARG', 'ILE', 'HIS', 'VAL', 'ASP', 'AMAN', 'PHE'}

# %%
# Define two atom selections
#selection1 = u.select_atoms("segid CARA and resnum 1 and name O6")
selection1 = u.select_atoms("segid PROB")
#selection2 = u.select_atoms("segid CARC and resnum 4 and name HO6")
selection2 = u.select_atoms("segid PROC")

# Calculate the center of mass for each frame  (or type 'compound='residues')
com_selection1 = np.array([selection1.center_of_mass(compound='group') for ts in u.trajectory])
com_selection2 = np.array([selection2.center_of_mass(compound='group') for ts in u.trajectory])
print(np.shape(com_selection1))
# Reshape the arrays for the distance calculation
com_selection1_reshaped = com_selection1.reshape((len(com_selection1), 3))
com_selection2_reshaped = com_selection2.reshape((len(com_selection2), 3))

# Calculate distances between centers of mass for each frame
distances_array = mda.lib.distances.distance_array(com_selection1_reshaped, com_selection2_reshaped, \
                                                   box=u.dimensions)

# Calculate the distnace between the two selected elements
#average_distances = np.mean(distances_array, axis=1)
distances=np.diag(distances_array)
print(distances[0:3])
# Print the average distances
#for frame, avg_distance in enumerate(average_distances):
#    print(f"Frame {frame + 1}: Average Distance = {avg_distance:.3f} Å")
# Out:
# (2501, 3)
# [48.076833   47.96153687 48.52881583]

# %%
# Plot the distances as a function of time
time_values = [ts.time for ts in u.trajectory]
np.savetxt('distance.dat', distances)
plt.plot(time_values, distances, label="Distance")
plt.xlabel("Time (ps)")
plt.ylabel("Distance (Å)")
plt.title("Time vs. Distance between Centers of Mass")
plt.legend()
plt.show()
